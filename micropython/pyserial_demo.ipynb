# %%
print("hello")
# Out:
# hello

# %%
import serial

PORT = '/dev/cu.usbmodem1301'
BAUDRATE = 115200

ser = serial.Serial(PORT, BAUDRATE)
content = ""

#try:
#    content = ser.readline()
#except: 
    print("nothing in the serial")
    
#print(content.decode("UTF"))

ser.write('Hello there board'.encode("UTF-8"))
# Out:
# nothing in the serial
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 14
#      11 except:
#      12     print("nothing in the serial")
# ---> 14 print(content.decode("UTF"))
#      16 ser.write('Hello there board'.encode("UTF-8"))
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
ser.write('beep'.encode("UTF-8"))
